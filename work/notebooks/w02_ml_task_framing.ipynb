# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Neel0289/FlyRank-Week1A1/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I chose the CTR / Engagement Opportunity Scoring lane because it focuses on identifying pages that receive good visibility but fail to convert that visibility into clicks or user engagement. The goal is to build a ranked opportunity list that helps reviewers prioritize pages that may benefit from metadata improvements, better intent matching, or engagement improvements. This problem is practical because review time is limited, so ranking the best opportunities can make the review process more efficient.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target is an opportunity score that ranks content pages based on their potential for improvement. Instead of predicting a simple yes/no outcome, the model estimates which pages should be prioritized by considering signals such as high impressions, low CTR, engagement metrics, search position, and content freshness. Since there is no directly observed "opportunity score" in the dataset, the target is a proxy label created using defined business rules and historical performance metrics. This allows the model to rank pages by expected optimization impact, helping reviewers focus on the highest-value opportunities first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# The primary success metric is NDCG (Normalized Discounted Cumulative Gain), as the goal is to rank the highest-value optimization opportunities at the top of the list. A good model consistently places pages with the greatest improvement potential in the highest ranks, allowing reviewers to spend their limited time on the most impactful pages. Ranking quality is more important than predicting an exact score because the business value comes from prioritization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# Each row represents a single content page (webpage/URL) along with its SEO, traffic, and engagement features, including impressions, clicks, CTR, average search position, search volume, and engagement metrics. The model treats each page as one observation and predicts an opportunity score for that page. These scores are then used to rank all pages by their optimization potential.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print(df[['content_id', 'client_id']].head())
# Out:
# Rows: 30000
# Columns: 44
#              content_id          client_id
# 0  content_304f48230142  client_f369cb89fc
# 1  content_a1fb4e703a9e  client_4e07408562
# 2  content_9aa793d4d895  client_7f2253d7e2
# 3  content_331d6c4de07b  client_19581e27de
# 4  content_d99b7a2d90ca  client_3fdba35f04

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule cannot reliably identify the best optimization opportunities because page performance depends on multiple interacting factors such as impressions, CTR, search position, engagement, and search volume. The relationship between these features is non-linear and varies across pages. A machine learning model can learn these complex patterns from historical data and produce a more accurate, data-driven ranking than any manually defined if-else rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
